# %%
import pandas as pd

file_path = "US_Accidents_March23.csv"  # CSV is in the same folder as this notebook

df_sample = pd.read_csv(file_path, nrows=50000)  # read first 50k rows
df_sample.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df_sample.shape
# Out:
# (50000, 46)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  object
#  1   Source                 50000 non-null  object
#  2   Severity               50000 non-null  int64
#  3   Start_Time             50000 non-null  object
#  4   End_Time               50000 non-null  object
#  5   Start_Lat              50000 non-null  float64
#  6   Start_Lng              50000 non-null  float64
#  7   End_Lat                0 non-null      float64
#  8   End_Lng                0 non-null      float64
#  9   Distance(mi)           50000 non-null  float64
#  10  Description            50000 non-null  object
#  11  Street                 50000 non-null  object
#  12  City                   50000 non-null  object
#  13  County                 50000 non-null  object
# ...

# %%
(df_sample.isna().mean() * 100).sort_values(ascending=False)
# Out:
# End_Lng                  100.000
# End_Lat                  100.000
# Wind_Chill(F)             95.006
# Precipitation(in)         93.448
# Wind_Speed(mph)           16.844
# Humidity(%)                1.278
# Weather_Condition          1.206
# Visibility(mi)             1.052
# Temperature(F)             0.912
# Pressure(in)               0.612
# Wind_Direction             0.534
# Weather_Timestamp          0.532
# Timezone                   0.014
# Zipcode                    0.014
# Airport_Code               0.014
# City                       0.000
# Street                     0.000
# Description                0.000
# County                     0.000
# Start_Lng                  0.000
# End_Time                   0.000
# Start_Lat                  0.000
# Source                     0.000
# ID                         0.000
# Start_Time                 0.000
# Severity                   0.000
# Distance(mi)               0.000
# Country                    0.000
# ...
